# %%
import html
import pprint
import re
from html.parser import HTMLParser


class ReutersParser(HTMLParser):

    def __init__(self, encoding='latin-1'):

        html.parser.HTMLParser.__init__(self)
        self._reset()
        self.encoding = encoding

    def _reset(self):
        self.in_body = False
        self.in_topics = False
        self.in_topic_d = False
        self.body = ""
        self.topics = []
        self.topic_d = ""

    def parse(self, fd):

        self.docs = []
        for chunk in fd:
            self.feed(chunk.decode(self.encoding))
            for doc in self.docs:
                yield doc
            self.docs = []
        self.close()

    def handle_starttag(self, tag, attrs):

        if tag == "reuters":
            pass
        elif tag == "body":
            self.in_body = True
        elif tag == "topics":
            self.in_topics = True
        elif tag == "d":
            self.in_topic_d = True 

    def handle_endtag(self, tag):

        if tag == "reuters":
            self.body = re.sub(r'\s+', r' ', self.body)
            self.docs.append( (self.topics, self.body) )
            self._reset()
        elif tag == "body":
            self.in_body = False
        elif tag == "topics":
            self.in_topics = False
        elif tag == "d":
            self.in_topic_d = False
            self.topics.append(self.topic_d)
            self.topic_d = ""  

    def handle_data(self, data):

        if self.in_body:
            self.body += data
        elif self.in_topic_d:
            self.topic_d += data

        
if __name__ == "__main__":
    # Open the first Reuters data set and create the parser
    filename = "reut2-003.sgm"
    parser = ReutersParser()

    # Parse the document and force all generated docs into
    # a list so that it can be printed out to the console
    doc = parser.parse(open(filename, 'rb'))
#    pprint.pprint(list(doc))
    topic= [result for result in list(doc) if result[0]]
#    print(topic)
    list_acq= [topics for topics in topic if 'acq' in topics[0] and topics[1]!='']

# %%
# import subprocess
# subprocess.check_call(["python", '-m', 'pip', 'install', 'spacy']) # install pkg

# %%
# import subprocess
# subprocess.check_call(["python", '-m', 'spacy', 'download', 'en']) # install pkg

# %%
nlp = spacy.load('en')
doc1 = nlp(list_acq[12][1])
displacy.render(doc1,style='ent',jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Allegheny International Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said it has entered into an agreement to merge with an affiliate of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     First Boston Inc's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  <
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     FPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# >
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     First Boston Corp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in a transaction valued at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     about 500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  mln dlrs.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Allegheny
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said the agreement calls for holders of its common to receive
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     24.60
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  dlrs a share. Holders of the company's
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2.19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  dlrs cumulative preference shares will receive
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  dlrs a share and those owning its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     11.25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  dlrs convertible preferred will receive
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     87.50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  dlrs a share.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Allegheny International
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said the agreement calls for the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     First Boston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  affiliate to start a cash tender offer for all outstanding shares of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Allegheny
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's common, cumulative preferred and convertible preferred. The company said
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     First Boston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has committed to provide all financing necessary to acquire such securities in the tender offer which is estimated to be
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     about 500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  mln dlrs. It said the agreement is also subject to the waiver by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     March 13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of certain conditions under the company's existing bank credit agreement.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Allegheny International's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; marg
# "USAir Group Inc said Piedmont Aviation Inc has agreed to be acquired for 69 dlrs per share. The company, in a newspaper advertisement, said it has started a tender offer for all Piedmont shares at that price, and the Piedmont board, with two directors absent, has unanimously approved the bid. The offer and withdrawal rights are to expire April Three unless extended, and the bid is to be followed by a merger at the same price. USAir said Piedmont has granted it an irrevocable option to buy up to 3,491,030 new shares under certain circumstances. Piedmont now has about 18.6 mln shares outstanding. USAir said the tender is conditioned on receipt of enough shares to give USAir at least a 50.1 pct interest in Piedmont on a fully diluted basis and approval by the U.S. Department of Transportation of a voting trust agreement permitting USAir to buy and hold shares pending review of its application to gain control of Piedmont. The company said its merger agreement with Piedmont provides that the offer is not to be amended without Piedmont's prior written consent in any way that would be adverse to Piedmont shareholders, but it said it could cut the number of shares to be bought without Piedmont's consent. USAir said it could reduce the number of Piedmont shares to be purchased in the offer to no less than the minimum number needed to cause the voting trust condition of the bid to be satisfied. In that case, it said if more than that minimum number of shares were tendered, it would buy shares on a pro rata basis. In February USAir had offered to pay 71 dlrs per share in cash for 50 pct of Piedmont's stock and 1.55 to 1.90 USAir shares for each remaining Piedmont share. Last week, Carl C. Icahn-controlled Trans World Airlines Inc <TWA> made a conditional offer to acquire USAir for 52 dlrs per share, a bid that was rejected by the USAir board. The Transportation Department on Friday rejected TWA's application to acquire USAir on the grounds that the application failed to comply with department regulations by omitting necessary information. TWA said it would refile today, providing the information needed. On Friday TWA said it had already acquired four mln shares or 15 pct of USAir. Reuter "

# %%
for token in doc1:
    print('"'+token.text+ '"', token.idx)
# Out:
# "Allegheny" 0
# "International" 10
# "Inc" 24
# "said" 28
# "it" 33
# "has" 36
# "entered" 40
# "into" 48
# "an" 53
# "agreement" 56
# "to" 66
# "merge" 69
# "with" 75
# "an" 80
# "affiliate" 83
# "of" 93
# "First" 96
# "Boston" 102
# "Inc" 109
# "'s" 112
# "<" 115
# "FPC" 116
# ">" 119
# "First" 121
# "Boston" 127
# "Corp" 134
# "in" 139
# "a" 142
# "transaction" 144
# "valued" 156
# "at" 163
# "about" 166
# "500" 172
# "mln" 176
# "dlrs" 180
# "." 184
# "Allegheny" 186
# "said" 196
# "the" 201
# "agreement" 205
# "calls" 215
# "for" 221
# "holders" 225
# "of" 233
# "its" 236
# "common" 240
# "to" 247
# "receive" 250
# "24.60" 258
# "dlrs" 264
# "a" 269
# "share" 271
# "." 276
# "Holders" 278
# "of" 286
# "the" 289
# "company" 293
# "'s" 300
# "2.19" 303
# "dlrs" 308
# "cumulative" 313
# "preference" 324
# "shares" 335
# "will" 342
# "receive" 347
# "20" 355
# "dlrs" 358
# "a" 363
# "share" 365
# "and" 371
# "those" 375
# "owning" 381
# "its" 388
# "11.25" 392
# "dlrs" 398
# "convertible" 403
# "preferred" 415
# "will" 425
# "receive" 430
# "87.50" 438
# "dlrs" 444
# "a" 449
# "share" 451
# "." 456
# "Allegheny" 458
# "International" 468
# "said" 482
# "the" 487
# "agreement" 491
# "calls" 501
# "for" 507
# "the" 511
# "First" 515
# "Boston" 521
# "affiliate" 528
# "to" 538
# "start" 541
# "a" 547
# "cash" 549
# "tender" 554
# "offer" 561
# "for" 567
# "all" 571
# "outstanding" 575
# "shares" 587
# "of" 594
# "Allegheny" 597
# "'s" 606
# "common" 609
# "," 615
# "cumulative" 617
# "preferred" 628
# "and" 638
# "convertible" 642
# "preferred" 654
# "." 663
# "The" 665
# "company" 669
# "said" 677
# "First" 682
# "Boston" 688
# "has" 695
# "committed" 699
# "to" 709
# "provide" 712
# "all" 720
# "financing" 724
# "necessary" 734
# "to" 744
# "acquire" 747
# "such" 755
# "securities" 760
# "in" 771
# "the" 774
# "tender" 778
# "offer" 785
# "which" 791
# "is" 797
# "estimated" 800
# "to" 810
# "be" 813
# "about" 816
# "500" 822
# "mln" 826
# "dlrs" 830
# "." 834
# "It" 836
# "said" 839
# "the" 844
# "agreement" 848
# "is" 858
# "also" 861
# "subject" 866
# "to" 874
# "the" 877
# "waiver" 881
# "by" 888
# "March" 891
# "13" 897
# "of" 900
# "certain" 903
# "conditions" 911
# "under" 922
# "the" 928
# "company" 932
# "'s" 939
# "existing" 942
# "bank" 951
# "credit" 956
# "agreement" 963
# "." 972
# "Allegheny" 974
# "International" 984
# "'s" 997
# "statement" 1000
# "did" 1010
# "not" 1014
# "name" 1018
# "or" 1023
# "describe" 1026
# "the" 1035
# "First" 1039
# "Boston" 1045
# "affiliate" 1052
# "involved" 1062
# "in" 1071
# "the" 1074
# "agreement" 1078
# "." 1087
# "It" 1089
# "did" 1092
# "say" 1096
# "the" 1100
# "offer" 1104
# "for" 1110
# "the" 1114
# "company" 1118
# "'s" 1125
# "stock" 1128
# "will" 1134
# "be" 1139
# "conditioned" 1142
# "also" 1154
# "on" 1159
# "the" 1162
# "valid" 1166
# "tender" 1172
# "of" 1179
# "securities" 1182
# "representing" 1193
# "at" 1206
# "least" 1209
# "a" 1215
# "majority" 1217
# "of" 1226
# "the" 1229
# "voting" 1233
# "power" 1240
# "for" 1246
# "the" 1250
# "election" 1254
# "of" 1263
# "directors" 1266
# "of" 1276
# "the" 1279
# "company" 1283
# "and" 1291
# "the" 1295
# "valid" 1299
# "tender" 1305
# "of" 1312
# "at" 1315
# "least" 1318
# "two" 1324
# "third" 1328
# "'s" 1333
# "of" 1336
# "the" 1339
# "outstanding" 1343
# "cumulative" 1355
# "preferred" 1366
# "and" 1376
# "convertible" 1380
# "preferred" 1392
# "shares" 1402
# "." 1408
# "Reuter" 1410

# %%
for sent in doc.sents:
    print()
    print(sent)

# %%
print([(token.text, token.tag_) for token in doc])
# Out:
# []

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-85f6b9bb679e> in <module>()
# ----> 1 for ent in doc.ents:
#       2     print(ent.text, ent.label_)
#
# AttributeError: 'generator' object has no attribute 'ents'

# %%
#doc = nlp(list_acq[2][1])
list_acq[2][1]

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)

# %%
for sent in doc.sents:
    print()
    print(sent)

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)

# %%
spacy.explain('GPE')

# %%
displacy.render(doc,style='ent',jupyter=True)

# %%
spacy.explain('ORG')

# %%
displacy.render(nlp(list_acq[12][1]),style='ent',jupyter=True)

# %%
for token in doc.ents:
    print(token.text, token.label_)

# %%
list_acq[12][1]
